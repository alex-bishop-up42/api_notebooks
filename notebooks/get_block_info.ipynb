# %% [markdown]
# ## UP42 Data and Prcessing Blocks
#
# Currently UP42 provides access to Earth Observation (EO) data using two methods. The first is through our host endpoint using the API. The second is through what are called Data Blocks. While this option will evovle and perhaps be depricated in the future, there are spcific parameters and information requiered for using them. This notebook shows you how to look for information regarding specific data or processing blocks

# %%
import requests
from pathlib import Path
import json

# %%
# PROJECT CREDENTIALS

# Path, load read json with credential secrets
proj_conf_file_path = Path.cwd()/'project-config-file.json'

# Opening JSON file and load into dict
open_proj_conf_file = open(proj_conf_file_path)
project_credentials = json.load(open_proj_conf_file)

# %%
# PROJECT CREDENTIALS

client_id = project_credentials['project_id']
client_secret = project_credentials['project_api_key']

# %%
# Get access token
def get_ptoken(client_id, client_secret):
    response = requests.post("https://$PROJ:$PKEY@api.up42.com/oauth/token",
                             data={"grant_type": "client_credentials"},
                             auth=(client_id, client_secret)
                            )
    
    return response.json()["access_token"]


# Get data products
def get_all_blocks(PTOKEN):
    response = requests.get("https://api.up42.com/blocks",
                            headers={"Authorization": "Bearer " + PTOKEN,
                                    "Content-Type" : "application/json"},
                           )
    return response.json()

# Block information
def get_specific_block_info(PTOKEN, BLOCK_ID):
    response = requests.get("https://api.up42.com/blocks/"+BLOCK_ID,
                            headers={"Authorization": "Bearer " + PTOKEN,
                                    "Content-Type" : "application/json"},
                           )
    return response.json()

# %%
PTOKEN = get_ptoken(client_id, client_secret)
products = get_all_blocks(PTOKEN)

# %%
# Block can be of type 'data' or 'processing'
#products['data'][2]['type']

# %%
for i in range(len(products['data'])):
    print(f"{i} <--> {products['data'][i]['id']} <--> {products['data'][i]['name']}")
# Out:
# 0 <--> 045019bb-06fc-4fa1-b703-318725b4d8af <--> oneatlas-spot-aoiclipped
# 1 <--> 3e146dd6-2b67-4d6e-a422-bb3d973e32ff <--> tiling
# 2 <--> 98c1acfa-c141-4095-b2e6-acf52d110178 <--> sobloo-s2-l1c-fullscene
# 3 <--> 18d09f1a-3197-4c27-a15a-54d099c31435 <--> oneatlas-pleiades-aoiclipped
# 4 <--> b623400c-c5ac-40af-bda2-0d2734aa9dd1 <--> sobloo-s1-grd-fullscene
# 5 <--> 8c6baae9-d50e-406c-b4ac-e211caa6229d <--> snap-polarimetric
# 6 <--> 05796180-75ea-4194-a836-7bd2325457cc <--> spacemetric-cloud-mask
# 7 <--> 4123fe57-3b79-4b74-a6ef-f7bb9d08e028 <--> aiads_rgb_t3
# 8 <--> a09e65e0-4c57-415e-8a33-969a287d89af <--> farearth/up42/house-detection
# 9 <--> 018dfb34-fc19-4334-8125-14fd7535f979 <--> sentinelhub-s2-aoiclipped
# 10 <--> 95519b2d-09d7-4cd0-a321-4d6a46bef6c1 <--> sentinelhub-landsat8-aoiclipped
# 11 <--> 6c379120-9789-448c-8ef0-bf80e9722f64 <--> coreg
# 12 <--> 6559a2d2-f023-461a-a14d-f094618c9ba0 <--> ndwi
# 13 <--> 98c6c8ec-0ec7-4019-bb3a-9a215ef6fea1 <--> ndvi
# 14 <--> ea459386-d2e1-4af2-b121-0b2cbe2314ef <--> building-detection
# 15 <--> 222c9742-ed19-4a2e-aa87-d6b58193cd31 <--> sobloo-s1-slc-fullscene
# 16 <--> 966517e3-bb68-4d40-ba8a-b9e5c5b4170d <--> evi
# 17 <--> 2301f05e-59e6-4cc7-96bd-723e46cd3b1c <--> savi
# 18 <--> c18cc521-b451-411b-a32e-63c6ffa11f8d <--> nbi
# 19 <--> 6e264c46-79bd-4a9a-b53b-b40894c1926e <--> msi
# 20 <--> ef6faaf5-8182-4986-bce4-4f811d2745e5 <--> nasa-modis
# 21 <--> f6c29b0a-75bd-44a1-a040-f18c9e881d1d <--> s2-superresolution
# 22 <--> 55d1087b-aec5-490d-9619-54ddb25ed1e0 <--> buildingbox
# 23 <--> defb134b-ca00-4e16-afa0-639c6dc0c5fe <--> oneatlas-pleiades-fullscene
# 24 <--> 63a69b97-1765-474e-b465-0b319b8d3b2d <--> oneatlas-spot-fullscene
# 25 <--> 8eb7e460-bb08-4a8e-bf7c-3f273b823f12 <--> deforestation
# 26 <--> 903f0435-d638-475e-bbe9-53b5664a22a8 <--> pansharpen
# 27 <--> b1c88381-6df0-4919-a194-5d5b3b1ee2f7 <--> sobloo-s1-grd-aoiclipped
# 28 <--> d0da4ac9-94c6-4905-80f5-c95e702ca878 <--> ndvi
# 29 <--> b8030602-f455-4120-a0e1-724ff369f049 <--> sports-detection
# 30 <--> 5b366455-1db4-49af-a709-64a508e2fb91 <--> srr-block
# 31 <--> b904d5db-754e-4d35-843e-c10d109d371a <--> burnt_area_extraction
# 32 <--> 2ac55313-240d-4a7e-ac47-b7e7786f1f25 <--> kmeans-clustering
# 33 <--> 0c0c217f-d926-4534-9072-2e4ead2d3e6c <--> sobloo-s5p
# 34 <--> 30f20bac-7499-4159-a4f3-38188a6e33e0 <--> crs-conversion
# 35 <--> ee08281c-d950-4258-81d5-e37187a9580e <--> sobloo-s3
# 36 <--> a9c26542-c431-4e89-b654-8cf5c3d2f0b6 <--> vectorising
# 37 <--> 56b2ba1a-000e-4dec-8657-0f85b7c7a6ac <--> dra
# 38 <--> e374ea64-dc3b-4500-bb4b-974260fb203e <--> sharpening
# 39 <--> 0f1ba0c4-75fb-4a11-bb0b-d65fd4214240 <--> superresolution
# 40 <--> 10cc89b3-5bf1-48a0-8dcd-04fa079ba1e9 <--> zonal-statistics
# 41 <--> a9397cf1-8ea6-4c03-9634-3678438c0508 <--> s5p-lvl3
# 42 <--> f427ad08-617d-4c33-8e32-32075352c3d3 <--> building_extraction
# 43 <--> fc8b89fa-8bed-4504-a4d2-b0dcd1aaef61 <--> flood_mapping
# 44 <--> ebc026fb-75a1-4d12-befd-24b3329bc5e8 <--> sm_veh-detection
# 45 <--> 06a81a0f-f5cd-4374-98fb-cf456feea295 <--> buildingdetection
# 46 <--> 54217695-73f4-4528-a575-a429e9af6568 <--> ship-identification
# 47 <--> c1678e74-70b5-47a7-b8fe-caebc4f470d9 <--> ais-hvt
# 48 <--> 00cc275a-fa04-44a5-9100-bffd6521b52e <--> ais-hvp
# 49 <--> 235addd2-3efe-424b-8c35-d9b41dfe0eb5 <--> meteomatics
# 50 <--> 0ef92e5e-7b0c-459b-a6f1-ef3a6317f9dd <--> lg_veh-detection
# 51 <--> 7bcfa144-e261-4228-b18e-4fc3d35e0b73 <--> oneatlas-pleiades-primary
# 52 <--> b1711286-c002-460d-8b28-b817fadc6cd0 <--> terracover-realsat-historical
# 53 <--> c766f8cc-e6d3-459b-b46c-ffeeca969edf <--> platforms-up42-up42pitch-tsx-block-eec
# 54 <--> 12e97249-abc5-4f58-b7fa-181b07e362cd <--> platforms-up42-up42pitch-tsx-block-ssc
# 55 <--> 7f7b257a-28cc-403e-8c8d-5b7d47c5c420 <--> gm-wmts-250mm
# 56 <--> f2acfa3c-bcf9-49d6-a7b8-79b122890987 <--> gm-wmts-125mm
# 57 <--> c94bb4cd-8ee2-40df-ba76-d332b8f48c6a <--> data-conversion-dimap
# 58 <--> e826be64-827b-4df9-b32d-56c528b8050d <--> data-conversion-netcdf
# 59 <--> 7f5645b3-59d7-4800-9dc3-924fb6f70db0 <--> snapship
# 60 <--> e6d0cb52-b649-4fca-9f2f-e215b7c02a37 <--> aws-s2-l2a
# 61 <--> f73c60f6-3f3c-4120-96cf-62b8d3019346 <--> nextmapone-5m
# 62 <--> 8e527ea8-c8b3-46ab-86c1-b05dbeee7b42 <--> nextmapone-10m
# 63 <--> 1f09fcb0-7f5c-4e91-b059-36df7f64d2c9 <--> nextmapone-1m
# 64 <--> 6cf139d5-bc8e-4201-9464-964899296d41 <--> advanced-water-related-geohazards-predictor
# 65 <--> 446645af-4722-42c5-be4e-88081e25ce51 <--> dymaxionlabs/up42-pools-detector
# 66 <--> 3c89d53e-6aec-43bb-b8b8-3e7f0132e28e <--> aws-l8-l1
# 67 <--> dd0ffe31-6d70-45a0-90d2-ddebe73ce807 <--> landcover
# 68 <--> df2ec03a-50c4-47ac-8a83-2db613869cf9 <--> openstreetmap
# 69 <--> eed51bcb-c7cc-4084-b518-6c59f46b48c8 <--> geotiff-custom
# 70 <--> 98066215-6c60-4076-bbb8-031987fec7fc <--> dimap-custom
# 71 <--> 99707a80-180e-4cf6-b903-741093bacd71 <--> fertilization-zoning-map
# 72 <--> 15edaaa5-7d82-4ca7-b0ea-17f7f2006590 <--> aws-modis
# 73 <--> f5bf583e-dacb-489c-95b4-0e8be95accc9 <--> tree-height-detection
# 74 <--> 4eb9fbbe-8fc3-48c6-a534-f3ad8ab15ebf <--> up42-countobjects
# 75 <--> b3dd4c58-6a2d-4ec2-8630-c9b5a3e93a31 <--> up42-exportdata-raster
# 76 <--> 3af41d3f-11cf-49ec-93c5-80b6e60c41e8 <--> up42-exportdata-vector
# 77 <--> 34bc86a2-3d5d-42dd-a597-a2a2dd3c9f5f <--> meteomatics-weather-map
# 78 <--> 75598899-26bf-4d1a-9a1c-b9d59bf0549a <--> exactearth-ais-query-vessel
# 79 <--> ad8c638f-dd99-4c55-ba9e-969d20ce48f2 <--> hexagon-aerial-15cm-streaming
# 80 <--> 455dfbf8-b8a9-4866-b518-3d59dfa85f83 <--> hexagon-aerial-15cm-download
# 81 <--> a0766df2-6cdd-42d8-b74a-3ba160dcdb43 <--> hexagon-aerial-30cm-download
# 82 <--> 65711d3a-c6e3-4350-a0d8-e1c1c6f79fe6 <--> hexagon-aerial-30cm-streaming
# 83 <--> dfc5d74f-d1e3-4e35-8c67-b36fd8cfe14e <--> airbus-globalseeps-sample
# 84 <--> ad083328-0fb4-4547-9f58-7815505d2ce4 <--> oneatlas-cloudmask
# 85 <--> 2b0181ef-4dba-45a2-974b-475175a6a712 <--> up42-ndvithreshold
# 86 <--> 34767300-5caf-472b-a684-a351212b5c14 <--> latitudo40-lst
# 87 <--> 3e24ed57-b07f-4d44-9957-5d5c0a457239 <--> oneatlas-spot-display
# 88 <--> 6ac78530-6200-42c1-b6a9-381a9f69d8ef <--> oneatlas-pleiades-display
# 89 <--> 0a1fc97b-dd5f-41ab-9208-658991e8abd6 <--> tree-detection
# 90 <--> b007810f-bc04-46bc-86d6-c6fbd49ee283 <--> shadow-detection
# 91 <--> 52060864-1346-40ba-b340-f47083bb2d8a <--> viewshed
# 92 <--> d2903c7b-b200-4afa-8676-11eec792ee15 <--> up42-import-geojson
# 93 <--> 08e0eb4f-c26f-4e4a-8a1e-2f39002624f7 <--> up42-terrasar-geotiff-conversion
# 94 <--> ca5be7bf-aad9-457d-a885-d029e9327e77 <--> oneatlas-basemap-streaming
# 95 <--> c45058c0-286e-44eb-ae1c-f33a03cac410 <--> oneatlas-basemap-download
# 96 <--> 33a4fd80-a822-47c0-a88e-b4fa1ac975c2 <--> terracover-realsat
# 97 <--> 061a4c71-044d-48b1-a3ae-91293779731c <--> airbus-globalseeps
# 98 <--> 705823cd-d295-4784-8131-06aa4afd0fcb <--> up42-waterfinder-water
# 99 <--> f23ccfe4-16b0-46a2-8fe2-4203daa1f267 <--> up42-waterfinder-flood
# 100 <--> 23de425c-7954-45fb-84c5-f75abe00e2d2 <--> catalystpro-insstack
# 101 <--> a737a343-0b17-4c92-b4bf-9813f9595bf2 <--> geocodis-builtup
# 102 <--> 70919851-c563-4e5e-9393-029cf10377c7 <--> esa-s5p-l3-gtiff
# 103 <--> 1cbfab83-8c73-451b-9176-72b42d2cb716 <--> up42-timeseries-image-statistics
# 104 <--> 1cdf4786-f524-41d5-9d88-b877c2a2bb4f <--> oneatlas-worlddem-12m
# 105 <--> 84f84805-d2c4-4068-90b5-b4b17d166b71 <--> meteomatics-agriculture
# 106 <--> 1f96c1a4-fb8c-46c1-9807-7efb8590eb77 <--> meteomatics-energy
# 107 <--> 7dfe3cc7-1e3c-4c59-b6d7-bf1e218640a6 <--> meteomatics-ocean
# 108 <--> e13d8e92-2763-4640-80d6-1501b2729707 <--> esa-s2-l2a-gtiff-analytic
# 109 <--> c4cb8913-2ef3-4e82-a426-65ea8faacd9a <--> esa-s2-l2a-gtiff-visual
# 110 <--> 8a89b7dd-b70b-48bb-8a02-bf020184f972 <--> fieldfinder
# 111 <--> 151c01ba-bd59-4078-8c4d-d4162b817738 <--> fieldfinder_iowa
# 112 <--> 93af9313-6066-4d97-bc3a-a0324482f4f3 <--> augmentor
# 113 <--> 893c63ee-18e5-45e2-a517-7322d317c223 <--> hyperverge-changedetection-pleiades
# 114 <--> c114df3a-b05f-48b0-b2dc-eeec3d85a8fe <--> hyperverge-changedetection-spot
# 115 <--> 81d4d7f3-7f08-4667-b34b-e5694ea980ad <--> landlines
# 116 <--> 6a613c6b-7f31-4aa8-88ff-92e66c313c63 <--> up42-16to8bit-conversion
# 117 <--> bffb13d6-3743-45e2-abb7-6b92e905c2e7 <--> building-detection
# 118 <--> a6e4cdc9-d3fd-4b09-bbf2-c44f32744982 <--> hexagon-aerial-30cm-eu-download
# 119 <--> 9cba92ca-9a82-4334-8775-d600d8fd397a <--> change_detector
# 120 <--> 278c452c-1bac-4724-bad6-7b2f6077aa9f <--> nextmapone-10m-dsm
# 121 <--> 74876773-4fab-45d0-a8a8-a9b637bba0ea <--> nextmapone-10m-dtm
# 122 <--> 07fe7b65-012c-4560-a5a5-4c37d2c61fe2 <--> nextmapone-1m-dsm
# 123 <--> 786d8629-8c7e-4590-ae28-c802c094ee60 <--> nextmapone-1m-dtm
# 124 <--> 625fd923-8ae6-4ac3-8e13-f51d3c977222 <--> nextmapone-6m
# 125 <--> 42c57f90-16dc-4008-801d-5d2a23e6ab95 <--> nextmapone-6m-dsm
# 126 <--> 93a3b9a9-640b-4f34-8394-65def39065ef <--> nextmapone-6m-dtm
# 127 <--> 4c8b168f-5455-444f-b588-47460f224ea7 <--> building-height-detection
# 128 <--> 62f1609a-7511-43a4-9c4c-fe39892b56f9 <--> rfviewshed
# 129 <--> 0e72f391-b6ed-4874-b728-a04206dd553c <--> up42-coregistration
# 130 <--> c0692741-8cd4-421c-94e1-e7fe2a4f0d0f <--> up42-processing-from-storage
# 131 <--> d633ef8b-2b7d-45fb-9950-4853576fc460 <--> worlddem-4ortho
# 132 <--> 8564e138-a04e-45cb-abec-ac78bc97a250 <--> worlddem-dtmlite
# 133 <--> c02dd029-b67a-4033-a59d-17fabcd031e1 <--> land-cover-data-10m-10-class
# 134 <--> a7ae7d12-788b-40c7-9a75-edd2a3b92cdb <--> oil-slick
# 135 <--> fec61cac-4c37-48ed-b4ca-352ce9022bf9 <--> wind_turbines
# 136 <--> 56cca64d-54e6-459e-8445-9f6eced7b17e <--> ship-detection
# 137 <--> d0c64db7-941b-41ce-89e9-8ac5d1a032d9 <--> change-detection
# 138 <--> 400e27a2-baa3-456a-96fe-20158b8c5ba1 <--> storage_tank
# 139 <--> e5ac35ff-994a-40db-91d2-af5ef20302fa <--> orbital_pleiades_aircraft
# 140 <--> 721c73a0-a859-4321-a39a-85637307cc79 <--> orbital_pleiades_cars
# 141 <--> 384b3a38-07d9-45d9-ad9e-4d27af8897c9 <--> orbital_pleiades_trucks
# 142 <--> 0922ecfd-12f1-4226-b004-29cf9b19ba86 <--> geopard-raster-processing-block
# 143 <--> dbb80eb9-32a2-4e52-b3af-09171d468bf9 <--> flood_detection
# 144 <--> 8d2ced9e-67b0-4822-a554-8fa219940052 <--> pleiadesneo-superresolution

# %%
search_key = 'sentinel'

for i in range(len(products['data'])):
    if search_key in products['data'][i]['name']:
        print(f"{i}  < -- > {products['data'][i]['id']}  < -- >  {products['data'][i]['name']}")
# Out:
# 9  < -- > 018dfb34-fc19-4334-8125-14fd7535f979  < -- >  sentinelhub-s2-aoiclipped
# 10  < -- > 95519b2d-09d7-4cd0-a321-4d6a46bef6c1  < -- >  sentinelhub-landsat8-aoiclipped

# %%
# Set the index value to the block you want more block information about
index_value = 9

# %%
BLOCK_ID = products['data'][index_value]['id']

# %%
PTOKEN = get_ptoken(client_id, client_secret)

# %%
block_info = get_specific_block_info(PTOKEN, BLOCK_ID)

# %%
block_info['data']['parameters']
# Out:
# {'bbox': {'type': 'array', 'default': None},
#  'time': {'type': 'dateRange',
#   'default': '2018-01-01T00:00:00+00:00/2021-12-31T23:59:59+00:00'},
#  'limit': {'type': 'integer', 'default': 1, 'minimum': 1},
#  'contains': {'type': 'geometry'},
#  'intersects': {'type': 'geometry'},
#  'zoom_level': {'type': 'integer', 'default': 14, 'maximum': 20, 'minimum': 3},
#  'time_series': {'type': 'array', 'default': None},
#  'max_cloud_cover': {'type': 'integer',
#   'default': 100,
#   'maximum': 100,
#   'minimum': 0}}

# %%
block_info
# Out:
# {'data': {'id': '018dfb34-fc19-4334-8125-14fd7535f979',
#   'displayId': '018dfb34',
#   'createdAt': '2019-04-05T08:34:53.095Z',
#   'updatedAt': '2021-06-23T13:51:58.600150Z',
#   'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe', 'type': 'USER'},
#   'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe', 'type': 'USER'},
#   'name': 'sentinelhub-s2-aoiclipped',
#   'displayName': 'Sentinel-2 Level 2 (GeoTIFF)',
#   'description': 'Provides Sentinel-2 imagery in GeoTIFF format.',
#   'containerUrl': 'registry.up42.com/marketplace/sentinelhub-s2-aoiclipped:TNyclPXD9oiBmZVTzgFbNqL01LFBTtbtQaQHFRj5',
#   'inputCapabilities': [],
#   'outputCapabilities': [],
#   'provider': 'Sentinel Hub',
#   'providerWebsite': 'https://www.sentinel-hub.com/',
#   'providerLogoUrl': 'https://metadata.up42.com/018dfb34-fc19-4334-8125-14fd7535f979/Sentinel_Hub_company_logo1576575636678.png',
#   'tags': ['Maritime',
#    'Oil, Gas, Minerals, and Energy',
#    'Transportation',
#    'Optical',
#    'Real Estate',
#    'Infrastructure and Utilities',
#    'Satellite',
#    'Agriculture',
#    'Insurance and Financial Services',
#    'Environmental Protection',
#    'Land Use and Management',
#    'Global'],
#   'isPublic': True,
#   'isPublicVersion': True,
#   'isValid': True,
#   'isRestricted': False,
#   'isAccessGranted': True,
#   'isCreditPurchaseRequired': True,
#   'isLimitStreamingDataAccess': False,
#   'parameters': {'bbox': {'type': 'array', 'default': None},
#    'time': {'type': 'dateRange',
#     'default': '2018-01-01T00:00:00+00:00/2021-12-31T23:59:59+00:00'},
#    'limit': {'type': 'integer', 'default': 1, 'minimum': 1},
#    'contains': {'type': 'geometry'},
#    'intersects': {'type': 'geometry'},
#    'zoom_level': {'type': 'integer',
#     'default': 14,
#     'maximum': 20,
#     'minimum': 3},
#    'time_series': {'type': 'array', 'default': None},
#    'max_cloud_cover': {'type': 'integer',
#     'default': 100,
#     'maximum': 100,
#     'minimum': 0}},
#   'type': 'DATA',
#   'isDryRunSupported': True,
#   'version': '2.3.6',
#   'metadata': {'overview': "Sentinel-2 Level 2 (GeoTIFF) provides atmospherically corrected Sentinel-2 data (L2A pre-processing or BOA). Sentinel 2 is a multi-spectral imaging mission, capturing visual, infrared and SWIR\xa0information. All Sentinel-2 data are available from the start of L2A processing, which is March 2017 for Europe and December 2018 globally. The data block provides an ability to get data for a chosen area of interest, either clipped per bounding box or custom geometry. The part of the image that does not intersect with these tiles will be black. The block outputs a single GeoTIFF file and will store the AOI within the output feature geometry. \xa0\n \n**Note:** This is a *Visual* imagery product that returns multispectral bands with 8 bits. Please check the corresponding block descriptions if they explicitly state that they can handle this type of data.\n \n| Band Category \xa0 \xa0 \xa0 \xa0| Spatial Resolution \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | Revisit \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 |\n| ---------------------|----------------------------------|-------------------------------|\n| Visible (4) \xa0 \xa0 \xa0 \xa0 \xa0| 10 m \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 5 days \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0|\n| Near-Infrared (6) \xa0 \xa0| 20 m \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 5 days \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0|\n| Short-wave IR (3) \xa0 \xa0| 60 m \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 5 days \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0|\n\n\n| Name \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0| Resolution | Description \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 |\n| ------------------|------------|-------------------------------------------------------|\n| B01 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 60 m \xa0 \xa0 \xa0 | Coastal aerosol, 442.7 nm (S2A), 442.2 nm (S2B) \xa0 \xa0 \xa0 |\n| B02 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 10 m \xa0 \xa0 \xa0 | Blue, 492.4 nm (S2A), 492.1 nm (S2B) \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0|\n| B03 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 10 m \xa0 \xa0 \xa0 | Green, 559.8 nm (S2A), 559.0 nm (S2B) \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 |\n| B04 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 10 m \xa0 \xa0 \xa0 | Red, 664.6 nm (S2A), 664.9 nm (S2B) \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 |\n| B05 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 20 m \xa0 \xa0 \xa0 | Vegetation red edge, 704.1 nm (S2A), 703.8 nm (S2B) \xa0 |\n| B06 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 20 m \xa0 \xa0 \xa0 |\tVegetation red edge, 740.5 nm (S2A), 739.1 nm (S2B) \xa0|\n| B07 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 10 m \xa0 \xa0 \xa0 | Vegetation red edge, 782.8 nm (S2A), 779.7 nm (S2B) \xa0 |\n| B08 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 10 m \xa0 \xa0 \xa0 | NIR, 832.8 nm (S2A), 832.9 nm (S2B) \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 |\n| B8A \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 20 m \xa0 \xa0 \xa0 | Narrow NIR, 864.7 nm (S2A), 864.0 nm (S2B) \xa0 \xa0 \xa0 \xa0 \xa0 \xa0|\n| B09 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 60 m \xa0 \xa0 \xa0 | Water vapour, 945.1 nm (S2A), 943.2 nm (S2B) \xa0 \xa0 \xa0 \xa0 \xa0|\n| B10 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 60 m \xa0 \xa0 \xa0 | SWIR – Cirrus, 1373.5 nm (S2A), 1376.9 nm (S2B) \xa0 \xa0 \xa0 |\n| B11 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 20 m \xa0 \xa0 \xa0 | SWIR, 1613.7 nm (S2A), 442.2 nm (S2B) \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 |\n| B12 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 20 m \xa0 \xa0 \xa0 | SWIR, 2202.4 nm (S2A), 442.2 nm (S2B) \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 |\n| AOT \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 10 m \xa0 \xa0 \xa0 | Aerosol Optical Thickness, based on Sen2Cor processor |\n| SCL \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 | 10 m \xa0 \xa0 \xa0 | Scene classification data, based on Sen2Cor processor |\n| S ...
#    'termsAndConditionsUrl': 'https://sentinel-hub.com/tos',
#    'blockThumbnailUrl': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/Sentinel-2-L2A-AOI-avatar.png',
#    'pricingStrategy': {'id': '30340db0-d2e9-47f5-86c1-7b70904c06ec',
#     'displayId': '30340db0',
#     'createdAt': '2021-06-23T13:51:58.599071Z',
#     'updatedAt': '2021-06-23T13:51:58.599071Z',
#     'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#      'type': 'USER'},
#     'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#      'type': 'USER'},
#     'type': 'MEGAPIXEL_OUTPUT',
#     'credits': 1.0},
#    'blockPricingStrategy': None,
#    'blockMarketplaceSampleData': [{'id': '928fcbf3-a151-4624-a681-448f81468b96',
#      'displayId': '928fcbf3',
#      'createdAt': '2021-06-23T13:51:58.599923Z',
#      'updatedAt': '2021-06-23T13:51:58.599923Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20True%20color.png',
#      'type': 'IMAGE'},
#     {'id': '8974b093-48e8-4a08-9473-a750a740f6b2',
#      'displayId': '8974b093',
#      'createdAt': '2021-06-23T13:51:58.599893Z',
#      'updatedAt': '2021-06-23T13:51:58.599893Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20Scene%20classification%20map.png',
#      'type': 'IMAGE'},
#     {'id': '872334c5-10cc-46ee-8812-8117d7fd6924',
#      'displayId': '872334c5',
#      'createdAt': '2021-06-23T13:51:58.599818Z',
#      'updatedAt': '2021-06-23T13:51:58.599818Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20NDVI.png',
#      'type': 'IMAGE'},
#     {'id': '469425c2-7cc6-43b9-a913-b4b15c24fa04',
#      'displayId': '469425c2',
#      'createdAt': '2021-06-23T13:51:58.599833Z',
#      'updatedAt': '2021-06-23T13:51:58.599833Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20False%20color.png',
#      'type': 'IMAGE'},
#     {'id': '2fe22db3-dc84-4fa0-ad3a-e57111338cac',
#      'displayId': '2fe22db3',
#      'createdAt': '2021-06-23T13:51:58.599937Z',
#      'updatedAt': '2021-06-23T13:51:58.599937Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20NDVI-clipped.png',
#      'type': 'IMAGE'},
#     {'id': '4ba47fb9-881a-4c31-af56-c191a7b53102',
#      'displayId': '4ba47fb9',
#      'createdAt': '2021-06-23T13:51:58.599803Z',
#      'updatedAt': '2021-06-23T13:51:58.599803Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20NDWI-clipped.png',
#      'type': 'IMAGE'},
#     {'id': '8baad967-211e-43f4-b68f-71e924bb78c4',
#      'displayId': '8baad967',
#      'createdAt': '2021-06-23T13:51:58.599788Z',
#      'updatedAt': '2021-06-23T13:51:58.599788Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20Moisture%20index-clipped.png',
#      'type': 'IMAGE'},
#     {'id': '677835cd-9e7c-4ec2-8849-3173d7ec5e6b',
#      'displayId': '677835cd',
#      'createdAt': '2021-06-23T13:51:58.599951Z',
#      'updatedAt': '2021-06-23T13:51:58.599951Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20False%20color-clipped.png',
#      'type': 'IMAGE'},
#     {'id': 'ea0c03c8-ac92-461d-a016-ef0642452107',
#      'displayId': 'ea0c03c8',
#      'createdAt': '2021-06-23T13:51:58.599966Z',
#      'updatedAt': '2021-06-23T13:51:58.599966Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20Moisture%20index.png',
#      'type': 'IMAGE'},
#     {'id': '53a74dee-cf7d-49b3-bd14-8961f4f9982a',
#      'displayId': '53a74dee',
#      'createdAt': '2021-06-23T13:51:58.599850Z',
#      'updatedAt': '2021-06-23T13:51:58.599850Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20SWIR-clipped.png',
#      'type': 'IMAGE'},
#     {'id': '48e73574-f3d3-497e-8bd6-d4b5c5981e1f',
#      'displayId': '48e73574',
#      'createdAt': '2021-06-23T13:51:58.599865Z',
#      'updatedAt': '2021-06-23T13:51:58.599865Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20SWIR.png',
#      'type': 'IMAGE'},
#     {'id': '5f8f7c31-1f5f-42f2-89e4-8407af92a97b',
#      'displayId': '5f8f7c31',
#      'createdAt': '2021-06-23T13:51:58.599772Z',
#      'updatedAt': '2021-06-23T13:51:58.599772Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20Scene%20classification%20map-clipped.png',
#      'type': 'IMAGE'},
#     {'id': 'edb7e64a-3c78-4bfe-82ad-692c3fa3b79b',
#      'displayId': 'edb7e64a',
#      'createdAt': '2021-06-23T13:51:58.599908Z',
#      'updatedAt': '2021-06-23T13:51:58.599908Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20True%20color-clipped.png',
#      'type': 'IMAGE'},
#     {'id': 'f31de3c3-b954-4b40-8ab0-8ce6ac189760',
#      'displayId': 'f31de3c3',
#      'createdAt': '2021-06-23T13:51:58.599741Z',
#      'updatedAt': '2021-06-23T13:51:58.599741Z',
#      'createdBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'updatedBy': {'id': 'eff16ad8-7fc3-46c7-b17b-952d7cb14afe',
#       'type': 'USER'},
#      'value': 'https://storage.googleapis.com/metadata-interstellar-staging/SentinelHub/Sentinel2_L2AAOI/2019-03-17%2C%20Sentinel-2A%20L2A%2C%20NDWI.png',
#      'type': 'IMAGE'}]},
#   'machineName': 'LARGE',
#   'manifestVersion': 2,
#   'capabilities': {'input': {},
#    'output': {'raster': {'up42_standard': {'bands': ['coastal',
#        'blue',
#        'green',
#        'red',
#        'rededge',
#        'rededge2',
#        'rededge3',
#        'nir',
#        'nir2',
#        'watervapour',
#        'swir',
#        'swir2',
#        'swir3'],
#       'dtype': 'uint8',
#       'format': 'GTiff',
#       'sensor': 'Sentinel2',
#       'resolution': 10,
#       'processing_level': 'l2'}}}}},
#  'error': None}

# %%
t = 'DATA'

for i in range(len(products['data'])):
    if t == products['data'][i]['type']:
        print(f"{i}  < -- > {products['data'][i]['id']}  < -- >  {products['data'][i]['name']}")
# Out:
# 0  < -- > 045019bb-06fc-4fa1-b703-318725b4d8af  < -- >  oneatlas-spot-aoiclipped
# 2  < -- > 98c1acfa-c141-4095-b2e6-acf52d110178  < -- >  sobloo-s2-l1c-fullscene
# 3  < -- > 18d09f1a-3197-4c27-a15a-54d099c31435  < -- >  oneatlas-pleiades-aoiclipped
# 4  < -- > b623400c-c5ac-40af-bda2-0d2734aa9dd1  < -- >  sobloo-s1-grd-fullscene
# 9  < -- > 018dfb34-fc19-4334-8125-14fd7535f979  < -- >  sentinelhub-s2-aoiclipped
# 10  < -- > 95519b2d-09d7-4cd0-a321-4d6a46bef6c1  < -- >  sentinelhub-landsat8-aoiclipped
# 15  < -- > 222c9742-ed19-4a2e-aa87-d6b58193cd31  < -- >  sobloo-s1-slc-fullscene
# 20  < -- > ef6faaf5-8182-4986-bce4-4f811d2745e5  < -- >  nasa-modis
# 23  < -- > defb134b-ca00-4e16-afa0-639c6dc0c5fe  < -- >  oneatlas-pleiades-fullscene
# 24  < -- > 63a69b97-1765-474e-b465-0b319b8d3b2d  < -- >  oneatlas-spot-fullscene
# 27  < -- > b1c88381-6df0-4919-a194-5d5b3b1ee2f7  < -- >  sobloo-s1-grd-aoiclipped
# 33  < -- > 0c0c217f-d926-4534-9072-2e4ead2d3e6c  < -- >  sobloo-s5p
# 35  < -- > ee08281c-d950-4258-81d5-e37187a9580e  < -- >  sobloo-s3
# 47  < -- > c1678e74-70b5-47a7-b8fe-caebc4f470d9  < -- >  ais-hvt
# 48  < -- > 00cc275a-fa04-44a5-9100-bffd6521b52e  < -- >  ais-hvp
# 49  < -- > 235addd2-3efe-424b-8c35-d9b41dfe0eb5  < -- >  meteomatics
# 51  < -- > 7bcfa144-e261-4228-b18e-4fc3d35e0b73  < -- >  oneatlas-pleiades-primary
# 52  < -- > b1711286-c002-460d-8b28-b817fadc6cd0  < -- >  terracover-realsat-historical
# 53  < -- > c766f8cc-e6d3-459b-b46c-ffeeca969edf  < -- >  platforms-up42-up42pitch-tsx-block-eec
# 54  < -- > 12e97249-abc5-4f58-b7fa-181b07e362cd  < -- >  platforms-up42-up42pitch-tsx-block-ssc
# 55  < -- > 7f7b257a-28cc-403e-8c8d-5b7d47c5c420  < -- >  gm-wmts-250mm
# 56  < -- > f2acfa3c-bcf9-49d6-a7b8-79b122890987  < -- >  gm-wmts-125mm
# 60  < -- > e6d0cb52-b649-4fca-9f2f-e215b7c02a37  < -- >  aws-s2-l2a
# 61  < -- > f73c60f6-3f3c-4120-96cf-62b8d3019346  < -- >  nextmapone-5m
# 62  < -- > 8e527ea8-c8b3-46ab-86c1-b05dbeee7b42  < -- >  nextmapone-10m
# 63  < -- > 1f09fcb0-7f5c-4e91-b059-36df7f64d2c9  < -- >  nextmapone-1m
# 66  < -- > 3c89d53e-6aec-43bb-b8b8-3e7f0132e28e  < -- >  aws-l8-l1
# 68  < -- > df2ec03a-50c4-47ac-8a83-2db613869cf9  < -- >  openstreetmap
# 69  < -- > eed51bcb-c7cc-4084-b518-6c59f46b48c8  < -- >  geotiff-custom
# 70  < -- > 98066215-6c60-4076-bbb8-031987fec7fc  < -- >  dimap-custom
# 72  < -- > 15edaaa5-7d82-4ca7-b0ea-17f7f2006590  < -- >  aws-modis
# 77  < -- > 34bc86a2-3d5d-42dd-a597-a2a2dd3c9f5f  < -- >  meteomatics-weather-map
# 78  < -- > 75598899-26bf-4d1a-9a1c-b9d59bf0549a  < -- >  exactearth-ais-query-vessel
# 79  < -- > ad8c638f-dd99-4c55-ba9e-969d20ce48f2  < -- >  hexagon-aerial-15cm-streaming
# 80  < -- > 455dfbf8-b8a9-4866-b518-3d59dfa85f83  < -- >  hexagon-aerial-15cm-download
# 81  < -- > a0766df2-6cdd-42d8-b74a-3ba160dcdb43  < -- >  hexagon-aerial-30cm-download
# 82  < -- > 65711d3a-c6e3-4350-a0d8-e1c1c6f79fe6  < -- >  hexagon-aerial-30cm-streaming
# 83  < -- > dfc5d74f-d1e3-4e35-8c67-b36fd8cfe14e  < -- >  airbus-globalseeps-sample
# 87  < -- > 3e24ed57-b07f-4d44-9957-5d5c0a457239  < -- >  oneatlas-spot-display
# 88  < -- > 6ac78530-6200-42c1-b6a9-381a9f69d8ef  < -- >  oneatlas-pleiades-display
# 92  < -- > d2903c7b-b200-4afa-8676-11eec792ee15  < -- >  up42-import-geojson
# 94  < -- > ca5be7bf-aad9-457d-a885-d029e9327e77  < -- >  oneatlas-basemap-streaming
# 95  < -- > c45058c0-286e-44eb-ae1c-f33a03cac410  < -- >  oneatlas-basemap-download
# 97  < -- > 061a4c71-044d-48b1-a3ae-91293779731c  < -- >  airbus-globalseeps
# 102  < -- > 70919851-c563-4e5e-9393-029cf10377c7  < -- >  esa-s5p-l3-gtiff
# 104  < -- > 1cdf4786-f524-41d5-9d88-b877c2a2bb4f  < -- >  oneatlas-worlddem-12m
# 105  < -- > 84f84805-d2c4-4068-90b5-b4b17d166b71  < -- >  meteomatics-agriculture
# 106  < -- > 1f96c1a4-fb8c-46c1-9807-7efb8590eb77  < -- >  meteomatics-energy
# 107  < -- > 7dfe3cc7-1e3c-4c59-b6d7-bf1e218640a6  < -- >  meteomatics-ocean
# 108  < -- > e13d8e92-2763-4640-80d6-1501b2729707  < -- >  esa-s2-l2a-gtiff-analytic
# 109  < -- > c4cb8913-2ef3-4e82-a426-65ea8faacd9a  < -- >  esa-s2-l2a-gtiff-visual
# 118  < -- > a6e4cdc9-d3fd-4b09-bbf2-c44f32744982  < -- >  hexagon-aerial-30cm-eu-download
# 120  < -- > 278c452c-1bac-4724-bad6-7b2f6077aa9f  < -- >  nextmapone-10m-dsm
# 121  < -- > 74876773-4fab-45d0-a8a8-a9b637bba0ea  < -- >  nextmapone-10m-dtm
# 122  < -- > 07fe7b65-012c-4560-a5a5-4c37d2c61fe2  < -- >  nextmapone-1m-dsm
# 123  < -- > 786d8629-8c7e-4590-ae28-c802c094ee60  < -- >  nextmapone-1m-dtm
# 124  < -- > 625fd923-8ae6-4ac3-8e13-f51d3c977222  < -- >  nextmapone-6m
# 125  < -- > 42c57f90-16dc-4008-801d-5d2a23e6ab95  < -- >  nextmapone-6m-dsm
# 126  < -- > 93a3b9a9-640b-4f34-8394-65def39065ef  < -- >  nextmapone-6m-dtm
# 130  < -- > c0692741-8cd4-421c-94e1-e7fe2a4f0d0f  < -- >  up42-processing-from-storage
# 131  < -- > d633ef8b-2b7d-45fb-9950-4853576fc460  < -- >  worlddem-4ortho
# 132  < -- > 8564e138-a04e-45cb-abec-ac78bc97a250  < -- >  worlddem-dtmlite
# 133  < -- > c02dd029-b67a-4033-a59d-17fabcd031e1  < -- >  land-cover-data-10m-10-class

# %%
t = 'DATA'

for i in range(len(products['data'])):
    if t == products['data'][i]['type']:
        print(f"{i}  < -- > {products['data'][i]['name']}")
# Out:
# 0  < -- > oneatlas-spot-aoiclipped
# 2  < -- > sobloo-s2-l1c-fullscene
# 3  < -- > oneatlas-pleiades-aoiclipped
# 4  < -- > sobloo-s1-grd-fullscene
# 9  < -- > sentinelhub-s2-aoiclipped
# 10  < -- > sentinelhub-landsat8-aoiclipped
# 15  < -- > sobloo-s1-slc-fullscene
# 20  < -- > nasa-modis
# 23  < -- > oneatlas-pleiades-fullscene
# 24  < -- > oneatlas-spot-fullscene
# 27  < -- > sobloo-s1-grd-aoiclipped
# 33  < -- > sobloo-s5p
# 35  < -- > sobloo-s3
# 47  < -- > ais-hvt
# 48  < -- > ais-hvp
# 49  < -- > meteomatics
# 51  < -- > oneatlas-pleiades-primary
# 52  < -- > terracover-realsat-historical
# 53  < -- > platforms-up42-up42pitch-tsx-block-eec
# 54  < -- > platforms-up42-up42pitch-tsx-block-ssc
# 55  < -- > gm-wmts-250mm
# 56  < -- > gm-wmts-125mm
# 60  < -- > aws-s2-l2a
# 61  < -- > nextmapone-5m
# 62  < -- > nextmapone-10m
# 63  < -- > nextmapone-1m
# 66  < -- > aws-l8-l1
# 68  < -- > openstreetmap
# 69  < -- > geotiff-custom
# 70  < -- > dimap-custom
# 72  < -- > aws-modis
# 77  < -- > meteomatics-weather-map
# 78  < -- > exactearth-ais-query-vessel
# 79  < -- > hexagon-aerial-15cm-streaming
# 80  < -- > hexagon-aerial-15cm-download
# 81  < -- > hexagon-aerial-30cm-download
# 82  < -- > hexagon-aerial-30cm-streaming
# 83  < -- > airbus-globalseeps-sample
# 87  < -- > oneatlas-spot-display
# 88  < -- > oneatlas-pleiades-display
# 92  < -- > up42-import-geojson
# 94  < -- > oneatlas-basemap-streaming
# 95  < -- > oneatlas-basemap-download
# 97  < -- > airbus-globalseeps
# 102  < -- > esa-s5p-l3-gtiff
# 104  < -- > oneatlas-worlddem-12m
# 105  < -- > meteomatics-agriculture
# 106  < -- > meteomatics-energy
# 107  < -- > meteomatics-ocean
# 108  < -- > esa-s2-l2a-gtiff-analytic
# 109  < -- > esa-s2-l2a-gtiff-visual
# 118  < -- > hexagon-aerial-30cm-eu-download
# 120  < -- > nextmapone-10m-dsm
# 121  < -- > nextmapone-10m-dtm
# 122  < -- > nextmapone-1m-dsm
# 123  < -- > nextmapone-1m-dtm
# 124  < -- > nextmapone-6m
# 125  < -- > nextmapone-6m-dsm
# 126  < -- > nextmapone-6m-dtm
# 130  < -- > up42-processing-from-storage
# 131  < -- > worlddem-4ortho
# 132  < -- > worlddem-dtmlite
# 133  < -- > land-cover-data-10m-10-class
